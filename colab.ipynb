# %%
# !git clone https://github.com/Esmaeil2023/waste-classification.git
# Out:
# Cloning into 'waste-classification'...
# remote: Enumerating objects: 1118, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 1118 (delta 17), reused 21 (delta 7), pack-reused 1077 (from 1)
# Receiving objects: 100% (1118/1118), 21.90 MiB | 18.15 MiB/s, done.
# Resolving deltas: 100% (128/128), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/waste-classification/
# !git checkout feature/khaled-evaluation
# Out:
# /content/waste-classification
# Branch 'feature/khaled-evaluation' set up to track remote branch 'feature/khaled-evaluation' from 'origin'.
# Switched to a new branch 'feature/khaled-evaluation'

# %%
# !python /content/waste-classification/src/train.py
# Out:
# Using device: cuda
#
# Loading data...
# TrashNetDataset loaded: 2535 images from /content/drive/MyDrive/ColabNotebooks/data/raw/Trashnet
# TrashNetDataset loaded: 2535 images from /content/drive/MyDrive/ColabNotebooks/data/raw/Trashnet
# TrashNetDataset loaded: 2535 images from /content/drive/MyDrive/ColabNotebooks/data/raw/Trashnet
# Split — train: 1774, val: 380, test: 381
#
# Building model: resnet50
# model.safetensors: 100% 102M/102M [00:01<00:00, 57.6MB/s]
#   Trainable parameters: 23,520,326
#
# Starting training for 5 epochs...
# ============================================================
#
# Epoch 1/5
#   Batch 10/111 | Loss: 1.7478
#   Batch 20/111 | Loss: 1.7586
#   Batch 30/111 | Loss: 1.7747
#   Batch 40/111 | Loss: 1.6114
#   Batch 50/111 | Loss: 1.7012
#   Batch 60/111 | Loss: 1.7618
#   Batch 70/111 | Loss: 1.7052
#   Batch 80/111 | Loss: 1.6103
#   Batch 90/111 | Loss: 1.7054
#   Batch 100/111 | Loss: 1.5455
#   Batch 110/111 | Loss: 1.5149
#
#   Train Loss: 1.6636 | Train Bal.Acc: 0.2644
#   Val   Loss: 1.5065 | Val   Bal.Acc: 0.3581
#   LR: 0.000090 | Time: 1268.3s
#   ✓ Saved best model (epoch 1)
#
# Epoch 2/5
#   Batch 10/111 | Loss: 1.5002
#   Batch 20/111 | Loss: 1.4272
#   Batch 30/111 | Loss: 1.5116
#   Batch 40/111 | Loss: 1.5225
#   Batch 50/111 | Loss: 1.4364
#   Batch 60/111 | Loss: 1.5411
#   Batch 70/111 | Loss: 1.4740
#   Batch 80/111 | Loss: 1.2877
#   Batch 90/111 | Loss: 1.1629
#   Batch 100/111 | Loss: 1.1284
#   Batch 110/111 | Loss: 1.0202
#
#   Train Loss: 1.3582 | Train Bal.Acc: 0.4675
#   Val   Loss: 1.0773 | Val   Bal.Acc: 0.6189
#   LR: 0.000065 | Time: 45.8s
#   ✓ Saved best model (epoch 2)
#
# Epoch 3/5
#   Batch 10/111 | Loss: 1.0972
#   Batch 20/111 | Loss: 1.0894
#   Batch 30/111 | Loss: 1.1232
#   Batch 40/111 | Loss: 0.9299
#   Batch 50/111 | Loss: 1.0390
#   Batch 60/111 | Loss: 0.9128
#   Batch 70/111 | Loss: 1.0480
#   Batch 80/111 | Loss: 0.7812
#   Batch 90/111 | Loss: 0.7729
#   Batch 100/111 | Loss: 1.3003
#   Batch 110/111 | Loss: 1.1705
#
#   Train Loss: 1.0623 | Train Bal.Acc: 0.5788
#   Val   Loss: 0.8416 | Val   Bal.Acc: 0.6649
#   LR: 0.000035 | Time: 45.2s
#   ✓ Saved best model (epoch 3)
#
# Epoch 4/5
#   Batch 10/111 | Loss: 1.0987
#   Batch 20/111 | Loss: 0.8552
#   Batch 30/111 | Loss: 0.7877
#   Batch 40/111 | Loss: 0.8606
#   Batch 50/111 | Loss: 1.1063
#   Batch 60/111 | Loss: 0.9215
#   Batch 70/111 | Loss: 1.1311
#   Batch 80/111 | Loss: 0.8507
#   Batch 90/111 | Loss: 0.9187
#   Batch 100/111 | Loss: 0.8473
#   Batch 110/111 | Loss: 0.8036
#
#   Train Loss: 0.9121 | Train Bal.Acc: 0.6130
#   Val   Loss: 0.7425 | Val   Bal.Acc: 0.6916
#   LR: 0.000010 | Time: 46.4s
#   ✓ Saved best model (epoch 4)
#
# Epoch 5/5
#   Batch 10/111 | Loss: 0.7653
#   Batch 20/111 | Loss: 0.9162
#   Batch 30/111 | Loss: 1.0134
#   Batch 40/111 | Loss: 0.9476
#   Batch 50/111 | Loss: 0.8182
#   Batch 60/111 | Loss: 0.9258
#   Batch 70/111 | Loss: 1.0740
#   Batch 80/111 | Loss: 1.0208
#   Batch 90/111 | Loss: 0.8353
#   Batch 100/111 | Loss: 0.7970
#   Batch 110/111 | Loss: 1.2170
#
#   Train Loss: 0.8666 | Train Bal.Acc: 0.6258
#   Val   Loss: 0.7105 | Val   Bal.Acc: 0.6943
#   LR: 0.000000 | Time: 46.2s
#   ✓ Saved best model (epoch 5)
#
# ============================================================
# Training complete! Best epoch: 5 | Best val loss: 0.7105
#
# Evaluating best model on test set...
#
# Test Balanced Accuracy: 0.6694
#
# Per-class results:
#   cardboard    — precision: 0.880 | recall: 0.772 | f1: 0.822
#   glass        — precision: 0.708 | recall: 0.840 | f1: 0.768
#   metal        — precision: 0.824 | recall: 0.778 | f1: 0.800
#   paper        — precision: 0.732 | recall: 0.969 | f1: 0.834
#   plastic      — precision: 0.781 | recall: 0.658 | f1: 0.714
#   trash        — precision: 0.000 | recall: 0.000 | f1: 0.000
