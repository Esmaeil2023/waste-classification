# %%
# !git clone https://github.com/Esmaeil2023/waste-classification.git
# Out:
# fatal: destination path 'waste-classification' already exists and is not an empty directory.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/waste-classification/
# !git checkout feature/khaled-evaluation
# Out:
# /content/waste-classification
# Already on 'feature/khaled-evaluation'
# Your branch is up to date with 'origin/feature/khaled-evaluation'.

# %%
# !python /content/waste-classification/src/train.py
# Out:
# Using device: cuda
#
# Loading data...
# TrashNetDataset loaded: 2535 images from /content/drive/MyDrive/ColabNotebooks/data/raw/Trashnet
# TrashNetDataset loaded: 2535 images from /content/drive/MyDrive/ColabNotebooks/data/raw/Trashnet
# TrashNetDataset loaded: 2535 images from /content/drive/MyDrive/ColabNotebooks/data/raw/Trashnet
# Split — train: 1774, val: 380, test: 381
#
# Building model: resnet50
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#   Trainable parameters: 23,520,326
#
# Starting training for 5 epochs...
# ============================================================
#
# Epoch 1/5
#   Batch 10/111 | Loss: 1.7471
#   Batch 20/111 | Loss: 1.7550
#   Batch 30/111 | Loss: 1.7704
#   Batch 40/111 | Loss: 1.6205
#   Batch 50/111 | Loss: 1.6996
#   Batch 60/111 | Loss: 1.7564
#   Batch 70/111 | Loss: 1.7129
#   Batch 80/111 | Loss: 1.6167
#   Batch 90/111 | Loss: 1.7118
#   Batch 100/111 | Loss: 1.5624
#   Batch 110/111 | Loss: 1.5326
#
#   Train Loss: 1.6633 | Train Bal.Acc: 0.2553
#   Val   Loss: 1.5020 | Val   Bal.Acc: 0.3507
#   LR: 0.000090 | Time: 39.6s
#   ✓ Saved best model (epoch 1)
#
# Epoch 2/5
#   Batch 10/111 | Loss: 1.5063
#   Batch 20/111 | Loss: 1.4433
#   Batch 30/111 | Loss: 1.5026
#   Batch 40/111 | Loss: 1.5125
#   Batch 50/111 | Loss: 1.4482
#   Batch 60/111 | Loss: 1.5268
#   Batch 70/111 | Loss: 1.4539
#   Batch 80/111 | Loss: 1.2318
#   Batch 90/111 | Loss: 1.1831
#   Batch 100/111 | Loss: 1.1174
#   Batch 110/111 | Loss: 1.0856
#
#   Train Loss: 1.3668 | Train Bal.Acc: 0.4642
#   Val   Loss: 1.0797 | Val   Bal.Acc: 0.6216
#   LR: 0.000065 | Time: 43.3s
#   ✓ Saved best model (epoch 2)
#
# Epoch 3/5
#   Batch 10/111 | Loss: 1.1384
#   Batch 20/111 | Loss: 1.1250
#   Batch 30/111 | Loss: 1.1120
#   Batch 40/111 | Loss: 0.9445
#   Batch 50/111 | Loss: 1.0493
#   Batch 60/111 | Loss: 0.9147
#   Batch 70/111 | Loss: 1.0515
#   Batch 80/111 | Loss: 0.8229
#   Batch 90/111 | Loss: 0.8182
#   Batch 100/111 | Loss: 1.2781
#   Batch 110/111 | Loss: 1.2165
#
#   Train Loss: 1.0675 | Train Bal.Acc: 0.5820
#   Val   Loss: 0.8408 | Val   Bal.Acc: 0.6699
#   LR: 0.000035 | Time: 44.3s
#   ✓ Saved best model (epoch 3)
#
# Epoch 4/5
#   Batch 10/111 | Loss: 1.0461
#   Batch 20/111 | Loss: 0.8618
#   Batch 30/111 | Loss: 0.8261
#   Batch 40/111 | Loss: 0.8837
#   Batch 50/111 | Loss: 1.1067
#   Batch 60/111 | Loss: 0.9421
#   Batch 70/111 | Loss: 1.1549
#   Batch 80/111 | Loss: 0.8586
#   Batch 90/111 | Loss: 0.9180
#   Batch 100/111 | Loss: 0.8359
#   Batch 110/111 | Loss: 0.8000
#
#   Train Loss: 0.9130 | Train Bal.Acc: 0.6163
#   Val   Loss: 0.7298 | Val   Bal.Acc: 0.7015
#   LR: 0.000010 | Time: 44.9s
#   ✓ Saved best model (epoch 4)
#
# Epoch 5/5
#   Batch 10/111 | Loss: 0.7658
#   Batch 20/111 | Loss: 0.8859
#   Batch 30/111 | Loss: 1.0131
#   Batch 40/111 | Loss: 0.9568
#   Batch 50/111 | Loss: 0.8406
#   Batch 60/111 | Loss: 0.9551
#   Batch 70/111 | Loss: 1.0497
#   Batch 80/111 | Loss: 0.9762
#   Batch 90/111 | Loss: 0.8261
#   Batch 100/111 | Loss: 0.7980
#   Batch 110/111 | Loss: 1.2117
#
#   Train Loss: 0.8677 | Train Bal.Acc: 0.6225
#   Val   Loss: 0.7076 | Val   Bal.Acc: 0.7055
#   LR: 0.000000 | Time: 43.6s
#   ✓ Saved best model (epoch 5)
#
# ============================================================
# Training complete! Best epoch: 5 | Best val loss: 0.7076
#
# Evaluating best model on test set...
# Traceback (most recent call last):
#   File "/content/waste-classification/src/train.py", line 322, in <module>
#     train(CONFIG)
#   File "/content/waste-classification/src/train.py", line 303, in train
#     checkpoint = torch.load(checkpoint_path, map_location=device)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1578, in load
#     raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# _pickle.UnpicklingError: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL numpy._core.multiarray.scalar was not an allowed global by default. Please use `torch.serialization.add_safe_globals([numpy._core.multiarray.scalar])` or the `torch.serialization.safe_globals([numpy._core.multiarray.scalar])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
