# %%
# !git clone https://github.com/Esmaeil2023/waste-classification.git
# Out:
# Cloning into 'waste-classification'...
# remote: Enumerating objects: 1149, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 1149 (delta 37), reused 41 (delta 16), pack-reused 1077 (from 1)
# Receiving objects: 100% (1149/1149), 21.91 MiB | 15.10 MiB/s, done.
# Resolving deltas: 100% (148/148), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/waste-classification/
# !git checkout feature/khaled-evaluation
# Out:
# /content/waste-classification
# Branch 'feature/khaled-evaluation' set up to track remote branch 'feature/khaled-evaluation' from 'origin'.
# Switched to a new branch 'feature/khaled-evaluation'

# %%
# !python /content/waste-classification/src/train.py
# Out:
# Using device: cuda
#
# Loading data...
# TrashNetDataset loaded: 2535 images from /content/drive/MyDrive/ColabNotebooks/data/raw/Trashnet
# TrashNetDataset loaded: 2535 images from /content/drive/MyDrive/ColabNotebooks/data/raw/Trashnet
# TrashNetDataset loaded: 2535 images from /content/drive/MyDrive/ColabNotebooks/data/raw/Trashnet
# Split — train: 1774, val: 380, test: 381
#
# Building model: resnet50
# model.safetensors: 100% 102M/102M [00:02<00:00, 47.5MB/s]
#   Trainable parameters: 23,520,326
#
# Starting training for 5 epochs...
# ...
#
# Epoch 1/5
#   Batch 10/111 | Loss: 1.7471
#   Batch 20/111 | Loss: 1.7585
#   Batch 30/111 | Loss: 1.7697
#   Batch 40/111 | Loss: 1.6176
#   Batch 50/111 | Loss: 1.7050
#   Batch 60/111 | Loss: 1.7461
#   Batch 70/111 | Loss: 1.7100
#   Batch 80/111 | Loss: 1.6138
#   Batch 90/111 | Loss: 1.6919
#   Batch 100/111 | Loss: 1.5493
#   Batch 110/111 | Loss: 1.5122
#
#   Train Loss: 1.6631 | Train Bal.Acc: 0.2639
# ...

# %%
# !python /content/waste-classification/src/evaluate.py
# Out:
# Using device: cuda
#
# Loading checkpoint: /content/drive/MyDrive/ColabNotebooks/resnet50_best.pth
# model.safetensors: 100% 102M/102M [00:02<00:00, 48.7MB/s]
#   Checkpoint epoch:    5
#   Val loss at save:    0.7105
#   Val bal.acc at save: 0.6943
# RealWasteDataset loaded: 3587 images
#   Skipped classes (not in TrashNet): Food Organics (411 images), Textile Trash (318 images), Vegetation (436 images)
#
# Evaluating on: RealWaste (OOD)
#   Total batches: 113
#   Batch 10/113
#   Batch 20/113
#   Batch 30/113
#   Batch 40/113
#   Batch 50/113
#   Batch 60/113
#   Batch 70/113
#   Batch 80/113
#   Batch 90/113
#   Batch 100/113
#   Batch 110/113
#
#   Results for RealWaste (OOD):
#   Loss:             1.5614
#   Balanced Acc:     0.3790 (37.9%)
#
#   Per-class breakdown:
#     cardboard              precision: 0.140 | recall: 0.161 | f1: 0.149
#     glass                  precision: 0.430 | recall: 0.286 | f1: 0.343
# ...
